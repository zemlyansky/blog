# %% [markdown]
# Markdown:

# %% [markdown]
# **Пробная запись в Jupyter Notebook**
#
# Код и график:

# %%
# Import the necessary packages and modules
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data
x = np.linspace(0, 10, 100)

# Plot the data
plt.plot(x, x, label='linear')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Формулы:

# %% [markdown]
# $$H←  ​​​​​0 ​+​ \frac{​​30(G−B)​​}{Vmax−Vmin}  ​​, if V​max​​ = R$$

# %% [markdown]
# Изображения:

# %% [markdown]
# ![Krot](img/local-img-test.png)
